# %%
import pandas as pd
import numpy as np
import openpyxl

# %%
#create a dataframe wit example_dt_1.csv
example_dt_1 = pd.read_csv('C:/Users/reloo/OneDrive/Escritorio/Hackathlon/mds-udg-viz-i-dgcp-hackathon-23/src/data/examples/example_dt_1.csv')
example_dt_1['Country Code'] = 0
example_dt_1['Country Code'] = ['AGO', 'BDI', 'BEN', 'BFA', 'BWA', 'CAF', 'CIV', 'CMR', 'COD','COG', 'DJI', 'DZA']
example_dt_1
# Out:
#            country  2005_min  2005_max  2005_avg  2006_min  2006_max  \
# 0        Argentina        17        37        27        12        39
# 1           Brasil        14        35        25        20        37
# 2         Colombia        16        38        27        19        36
# 3       Costa Rica        16        36        26        15        35
# 4          Ecuador        16        36        26        15        35
# 5      El Salvador        16        36        26        15        35
# 6        Guatemala        16        36        26        15        35
# 7         Honduras        16        36        26        15        35
# 8           México        16        36        26        15        35
# 9           España        16        38        27        19        36
# 10  Estados Unidos        16        38        27        19        36
# 11       Nicaragua        16        36        26        15        35
#
# ...

# %%
population = pd.read_excel('C:/Users/reloo/OneDrive/Escritorio/Hackathlon/mds-udg-viz-i-dgcp-hackathon-23/src/data/pop_bancomundial_excel.xlsx')
population
#rename the column iso_A3 to iso_code
#population.rename(columns={'ISO_A3':'iso_code'}, inplace=True)
#population=population[(population['Pre2012Ce']>2006)&(population['Pre2012Ce']<2016)]
# Out:
#         Country Name Country Code    Indicator Name Indicator Code  \
# 0              Aruba          ABW  Población, total    SP.POP.TOTL
# 1                NaN          AFE  Población, total    SP.POP.TOTL
# 2         Afganistán          AFG  Población, total    SP.POP.TOTL
# 3                NaN          AFW  Población, total    SP.POP.TOTL
# 4             Angola          AGO  Población, total    SP.POP.TOTL
# ..               ...          ...               ...            ...
# 261           Kosovo          XKX  Población, total    SP.POP.TOTL
# 262  Yemen, Rep. del          YEM  Población, total    SP.POP.TOTL
# 263        Sudáfrica          ZAF  Población, total    SP.POP.TOTL
# 264           Zambia          ZMB  Población, total    SP.POP.TOTL
# 265         Zimbabwe          ZWE  Población, total    SP.POP.TOTL
#
#             1960         1961         1962         1963         1964  \
# 0        54608.0      55811.0      56682.0      57475.0      58178.0
# ...

# %%
#join the two dataframes by Country Code
examp_pop = pd.merge(example_dt_1, population, on='Country Code')
examp_pop
# Out:
#            country  2005_min  2005_max  2005_avg  2006_min  2006_max  \
# 0        Argentina        17        37        27        12        39
# 1           Brasil        14        35        25        20        37
# 2         Colombia        16        38        27        19        36
# 3       Costa Rica        16        36        26        15        35
# 4          Ecuador        16        36        26        15        35
# 5      El Salvador        16        36        26        15        35
# 6        Guatemala        16        36        26        15        35
# 7         Honduras        16        36        26        15        35
# 8           México        16        36        26        15        35
# 9           España        16        38        27        19        36
# 10  Estados Unidos        16        38        27        19        36
# 11       Nicaragua        16        36        26        15        35
#
# ...

# %%
examp_pop_t = examp_pop.T
examp_pop_t
# Out:
#                   0           1           2           3          4   \
# country    Argentina      Brasil    Colombia  Costa Rica    Ecuador
# 2005_min          17          14          16          16         16
# 2005_max          37          35          38          36         36
# 2005_avg          27          25          27          26         26
# 2006_min          12          20          19          15         15
# ...              ...         ...         ...         ...        ...
# 2017      30208628.0  11155593.0  11596779.0  19835858.0  2401840.0
# 2018      31273533.0  11493472.0  11940683.0  20392723.0  2451409.0
# 2019      32353588.0  11874838.0  12290444.0  20951639.0  2499702.0
# 2020      33428486.0  12220227.0  12643123.0  21522626.0  2546402.0
# 2021      34503774.0  12551213.0  12996895.0  22100683.0  2588423.0
#
#                    5           6           7           8          9   \
# country   El Salvador   Guatemala    Honduras      México     España
# ...
